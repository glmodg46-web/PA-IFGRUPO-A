# %% [markdown]
# <a href="https://colab.research.google.com/github/glmodg46-web/PA-IFGRUPO-A/blob/main/19_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saldo = 1000
opcao = 0

while opcao != 4:
    print("    CAIXA ELETRÔNICO   ")
    print("opção 1: Consultar saldo")
    print("opção 2: Depositar")
    print("opção 3: Sacar")
    print("opção 4: Sair")

    opcao = int(input("Escolha uma opção: "))

    if opcao == 1:
        print(f"Seu saldo atual é: R${saldo}")

    elif opcao == 2:
        deposito = float(input("Digite o valor do depósito: R$"))

        if deposito > 0:
            saldo += deposito
            print("Depósito realizado com sucesso!")
        else:
            print("Valor inválido.")

    elif opcao == 3:
        saque = float(input("Digite o valor do saque: "))

        if saque <= saldo:
            saldo -= saque
            print("Saque realizado com sucesso!")
        else:
            print("Saldo insuficiente.")

    elif opcao == 4:
        print("Saindo do sistema")

    else:
        print("Opção inválida. Tente novamente")

print("Estarei a sua disposição!")
# Out:
#     CAIXA ELETRÔNICO
# opção 1: Consultar saldo
# opção 2: Depositar
# opção 3: Sacar
# opção 4: Sair
# Escolha uma opção: 1
# Seu saldo atual é: R$1000
#     CAIXA ELETRÔNICO
# opção 1: Consultar saldo
# opção 2: Depositar
# opção 3: Sacar
# opção 4: Sair
# Escolha uma opção: 2
# Digite o valor do depósito: R$200
# Depósito realizado com sucesso!
#     CAIXA ELETRÔNICO
# opção 1: Consultar saldo
# opção 2: Depositar
# opção 3: Sacar
# opção 4: Sair
# Escolha uma opção: 4
# Saindo do sistema
# Estarei a sua disposição!
