# %% [markdown]
# <a href="https://colab.research.google.com/github/glmodg46-web/PA-IFGRUPO-A/blob/main/aula_dia_02_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


numero_secreto = random.randint(0, 10)
tentativas = 3

print("-- JOGO DE ADIVINHAÇÃO --")
print("Tente adivinhar o número secreto entre 0 e 10")

while tentativas > 0:
    palpite = int(input(f" Você tem {tentativas} tentativas. Digite seu palpite: "))


    if palpite == numero_secreto:
        print("Parabens voce acertou o numero")
        break


    diferenca = abs(palpite - numero_secreto)


    if diferenca == 1:
        print("Quente")
    elif diferenca == 2:
        print("Morno")
    elif diferenca >= 3:
        print("Frio")

    tentativas -= 1

if tentativas == 0:
    print(f" Fim de jogo O numero secreto era {numero_secreto}.")
# Out:
# -- JOGO DE ADIVINHAÇÃO --
# Tente adivinhar o número secreto entre 0 e 10
#  Você tem 3 tentativas. Digite seu palpite: 9
# Quente
#  Você tem 2 tentativas. Digite seu palpite: 10
# Parabens voce acertou o numero
