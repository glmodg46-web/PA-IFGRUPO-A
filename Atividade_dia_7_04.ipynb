# %% [markdown]
# <a href="https://colab.research.google.com/github/glmodg46-web/PA-IFGRUPO-A/blob/main/Atividade_dia_7_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Questão 1


#Entrada

nome = str (input ("digite o seu nome:  "))
idade = int (input ( "digite sua idade: "))

# Processamento / Saída

if idade <= 17:
  print (f"{nome}, você tem {idade} anos de idade, você é criança.")

elif idade <= 18 and idade <=59:
  print (f"{nome}, você tem {idade} anos de idade, você é adulto.")


else:
  print(f"{nome}, você tem {idade} anos de idade, você é idoso.")
# Out:
# digite o seu nome:  Gui
# digite sua idade: 18
# Gui, você tem 18 anos de idade, você é adulto.

# %%
#Questão 2 Cálculo de desconto

# Entrada
nome = str (input ("digite o seu nome:  "))
compra = float (input("Coloque o valor da compra: "))


# Processamento / Saída

if compra <= 100:
  print (f"{nome} Você gastou {compra} você não terá desconto")

if compra >= 101 and compra <= 500:
    print (f"{nome} Você gastou {compra} Você Terá 10% de desconto")

if compra >= 500:
    print (f"{nome} Você gastou {compra} Você Terá 20% de desconto")
# Out:
# digite o seu nome:  joao
# Coloque o valor da compra: 900
# joao Você gastou 900.0 Você Terá 20% de desconto

# %%
#Questão 3
#Entrada

lado1 = int (input("digite o lado do triangulo: "))
lado2 = int (input("digite o lado do triangulo: "))
lado3 = int (input("digite o lado do triangulo: "))

#Processamento / Saída

if lado1 == lado2 and lado1 == lado3:
  print ("Diante a suas informaçoes seu trinagulo é um triangulo valido")
# Out:
# digite o lado do triangulo: 60
# digite o lado do triangulo: 60
# digite o lado do triangulo: 60
# Diante a suas informaçoes seu trinagulo é um triangulo valido

# %%
#Questão 4

# Entrada

Energia = int (input("Digite a Energia do seu Personagem: "))

#Processamento / Saída

if Energia >= 1 and a <= 30:
  print (f" Seu personagem tem energia igual a {Energia}. Ele está em estado critico.")

elif Energia >= 31 and a <= 70:
  print (f" Seu personagem tem energia igual a {Energia}. Ele está Normal.")

else:
    print (f" Seu personagem tem energia igual a {Energia}. Ele está saudavel.")
# Out:
# Digite a Energia do seu Personagem: 30
#  Seu personagem tem energia igual a 30. Ele está saudavel.

# %%
#Questão 5
#Entrada

Nome = str(input("Escreva Seu nome?"))

idade = float(input("Qual a sua idade?"))

media = float(input("Qual a média que você obteve?"))


#Processamento

if media <= 7:
  print (f"{nome}, você tem {idade} anos de idade, você  teve {media} foi aprovado.")

elif media <= 6:
  print (f"{nome}, você tem {idade} anos de idade, você teve {media} foi Reprovado.")
# Out:
# Escreva Seu nome?joao
# Qual a sua idade?10
# Qual a média que você obteve?6
# joao, você tem 10.0 anos de idade, você  teve 6.0 foi aprovado.

# %%
#Questao 6

# Entrada
nome = str (input ("digite o seu nome:  "))
desempenho = float (input("Coloque o valor do desempenho: "))


# Processamento / Saída

if desempenho >= 5:
  print (f"{nome} voce tem {desempenho} você não terá bonus")

if desempenho >= 5 and desempenho >= 7:
    print (f"{nome} Você tem {desempenho} Você Terá 5% de bonus")

if desempenho >= 8 and desempenho >= 9:
    print (f"{nome} Você tem {desempenho} Você Terá 10% de bonus")
# Out:
# digite o seu nome:  Jose
# Coloque o valor do desempenho: 9
# Jose voce tem 9.0 você não terá bonus
# Jose Você tem 9.0 Você Terá 5% de bonus
# Jose Você gastou 9.0 Você Terá 10% de desconto
